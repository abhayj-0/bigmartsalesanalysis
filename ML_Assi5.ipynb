# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data_Assig5.csv')
df1 = pd.read_csv('data_Assig5.csv')
df2 = pd.read_csv('data_Assig5.csv');
print('*'*20+'part a'+'*'*20)
gg=df.axes
for x in gg:
    print(df.isnull())
    print(df.sum())
# Out:
# ********************part a********************
#       Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    False     False    False    False     False        False     False
# 1    False     False    False    False     False        False     False
# 2    False     False    False    False     False        False     False
# 3    False     False    False    False     False        False     False
# 4    False     False    False    False     False        False     False
# 5    False     False    False    False     False        False     False
# 6    False     False    False    False     False        False     False
# 7    False     False    False    False     False        False     False
# 8    False     False    False    False     False        False     False
# 9    False     False    False    False     False        False     False
# 10   False     False    False    False     False        False     False
# ...

# %%
print('*'*20+'part b'+'*'*20)
    #to remove values
print(df.dropna())
print('*'*20+'part c'+'*'*20)
print(df.fillna(df1.mean()))
# Out:
# ********************part b********************
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
import pandas as pd
df2=pd.read_csv('data_Assig5.csv')

MinTemp=df.MinTemp
MaxTemp=df.MaxTemp
Temp9am=df.Temp9am
Temp3pm=df.Temp3pm
mt=MinTemp.dtype
mat=MinTemp.dtype
t9=Temp9am.dtype
t3=Temp3pm.dtype
df5=pd.Series(MinTemp)
df6=pd.Series(MaxTemp)
df7=pd.Series(Temp9am)
df8=pd.Series(Temp3pm)
print("datatype of Min Temp: \n"+str(mt))
print("datatype of Max Temp: \n"+str(mat))
print("datatype of Temp9am: \n"+str(t9))
print("datatype of Temp3pm: \n"+str(t3))
print("Min Temp Series: \n"+str(df5))
print("Max Temp Series: \n"+str(df6))
print("Temp9am Series: \n"+str(df7))
print("Temp3pm Series: \n"+str(df8))
#for row in df2:
#    content = list(row[i] for i in MinTemp)
#   print(content)
# Out:
# datatype of Min Temp:
# float64
# datatype of Max Temp:
# float64
# datatype of Temp9am:
# float64
# datatype of Temp3pm:
# float64
# Min Temp Series:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
# 5       6.2
# 6       6.1
# 7       8.3
# 8       8.8
# 9       8.4
# 10      9.1
# 11      8.5
# 12     10.1
# 13     12.1
# 14     10.1
# 15     12.4
# 16     13.8
# 17     11.7
# 18     12.4
# 19     15.6
# 20     15.3
# 21     16.4
# 22     12.8
# 23     12.0
# 24     15.4
# 25     15.6
# 26     13.3
# 27     12.9
# 28     15.1
# 29     13.6
#        ...
# 336     5.6
# 337    16.8
# 338    14.4
# 339    10.3
# 340    11.2
# 341     0.3
# 342     0.5
# 343     0.5
# 344     4.6
# 345     8.2
# 346     4.5
# 347     6.7
# 348    11.9
# 349     9.2
# 350     4.4
# 351     5.0
# 352     6.7
# 353     8.3
# 354    11.3
# 355     9.0
# 356     3.4
# 357     3.2
# 358     0.9
# 359     3.3
# 360     7.9
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# ...
