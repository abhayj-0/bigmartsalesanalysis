# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('data_Assig7.csv', delimiter=";")

# %%
#ques 1
df.describe(include="all")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fixed acidity</th>
#       <th>volatile acidity</th>
#       <th>citric acid</th>
#       <th>residual sugar</th>
#       <th>chlorides</th>
#       <th>free sulfur dioxide</th>
#       <th>total sulfur dioxide</th>
#       <th>density</th>
#       <th>pH</th>
#       <th>sulphates</th>
#       <th>alcohol</th>
#       <th>quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
#       <td>4898.000000</td>
# ...

# %%
#ques2
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#ques 3:
plt.hist(x='alcohol' ,data=df,bins=50)
plt.grid()
plt.title('Count plot of alcohol in white wine')
# Out:
# Text(0.5,1,'Count plot of alcohol in white wine')

# %%
plt.hist(x='citric acid',data=df,bins=10)
plt.grid()
plt.title='count plot of citric acid in white wines'

# %%
sns.distplot(df['pH'])
print("ph levels of white wine")
# Out:
# C:\Users\family\PycharmProjects\ML\venv\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ph levels of white wine

# %%
sns.distplot(df['density'])
print("density of white wine")
# Out:
# C:\Users\family\PycharmProjects\ML\venv\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ph levels of white wine

# %%
sns.distplot(df['quality'])
print("quality of white wine")
# Out:
# C:\Users\family\PycharmProjects\ML\venv\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# quality of white wine

# %%
sns.kdeplot(df['free sulfur dioxide'], shade=True)
print("free sulfur dioxide levels in white whine")

# %%
plt.hist(df['density'],bins=10 )
print('free sulphur dioxide')
plt.xlabel('density')
plt.ylabel('quality')
# Out:
# free sulphur dioxide
# Text(0,0.5,'quality')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)

# %%
# Out:
# C:\Users\family\PycharmProjects\ML\venv\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-50-68d14c9f0553> in <module>()
#       1 f = sns.FacetGrid(df, col="alcohol", col_wrap=4, size=1.5)
#       2 sns.set(color_codes=True)
# ----> 3 df=sns.load_dataset("df")
#       4 ax = sns.regplot(x="density",y="quality",data=df,color="g",x_jitter=0.3,y_jitter=0.3)
#
# C:\Users\family\PycharmProjects\ML\venv\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
# ...
